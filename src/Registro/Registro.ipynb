# %% [markdown]
# <h2>Clase que emula un 'record' o registro de lo que sucedió durante un evento</h2>
# <p>(en nuestro contexto, una partida del juego del Gato y el Ratón).</p>
# <ul>
#     <li>@author Javier Valdes Nava</li>
#     <li>@since 2025</li>
#     <li>@version 1.0</li>
# </ul>
#
# <h3>ATRIBUTOS</h3>
# <ul>
#     <li>str resultado : El resultado del juego (es decir, si ganó el ratón o si ganaron los gatos)</li>
#     <li>str gato1 : Los movimientos del gato1 durante la partida</li>
#     <li>str gato2 : Los movimientos del gato2 durante la partida</li>
#     <li>str gato3 : Los movimientos del gato3 durante la partida</li>
#     <li>str gato4 : Los movimientos del gato4 durante la partida</li>
#     <li>str jugadasRaton : Los movimientos del ratón durante la partida</li>
#     <li>int rondas : El número de rondas jugadas.</li>
# </ul>
#
# <h3>METODOS</h3>

# %%
class Registro:
    #/**
	#*
	#* Constructor por parametros de una instancia de la clase Registro.
	#* @param p1 El primer jugador que vamos a guardar en el registro del juego (el que perdió).
	#* @param p2 El segundo jugador que vamos a guardar en el registro del juego (el que ganó).
	#* @param movs Las jugadas en las que se acabó el juego (entre mas grandes, mejor el juego).
	#*
	#*/
    def __init__(self, resultado, gato1, gato2, gato3, gato4, jugadasRaton, rondas):
        self.resultado = resultado
        self.gato1 = gato1
        self.gato2 = gato2
        self.gato3 = gato3
        self.gato4 = gato4
        self.jugadasRaton = jugadasRaton
        self.rondas = rondas
        
	
	#						// ## Métodos para obtener
	#/**
	#*
	#* Metodo de acceso para el jugador 1.
	#* @return String - El nombre registrado para el jugador 1.
	#*
	#*/
	#def obtenerResultado()
	#{
	#	return self.resultado
	#}
	
	#/**
	#*
	#* Metodo de acceso para el jugador 2.
	#* @return String - El nombre registrado para el jugador 2.
	#*
	#*/
	#def obtenerGato1()
	#{
	#	return self.gato1
	#}

    #def obtenerGato2()
	#{
	#	return self.gato2
	#}

    #def obtenerGato3()
	#{
	#	return self.gato3
	#}

    #def obtenerGato4()
	#{
	#	return self.gato4
	#}
	
	#/**
	#*
	#* Metodo para acceder a la cantidad de rondas jugadas.
	#* @return int - La cantidad de partidas jugadas (como entero de 32 bits).
	#*
	#*/
	#def obtenerJugadasRaton()
	#{
	#	return self.jugadasRaton
	#}

    #def obtenerRondas()
	#{
	#	return self.rondas
	#}


    
	#						// ## Métodos para asignar
	
	#/**
	#*
	#* Metodo para modificar al jugador 1.
	#* @param nvo El nuevo jugador 1.
	#*
	#*/
	#def asignarResultado(String nvo)
	#{
	#	self.resultado = nvo;
	#}
	
	#/**
	#*
	#* Metodo para modificar al jugador 2.
	#* @param nvo El nuevo jugador 2.
	#*
	#*/
	#def asignarGato1(String nvo)
	#{
	#	self.gato1 = nvo;
	#}

    #def asignarGato2(String nvo)
	#{
	#	self.gato2 = nvo;
	#}

    #def asignarGato3(String nvo)
	#{
	#	self.gato3 = nvo;
	#}

    #def asignarGato4(String nvo)
	#{
	#	self.gato4 = nvo;
	#}

    #def asignarJugadasRaton(String nvo)
	#{
	#	self.jugadasRaton = nvo;
	#}

    #def asignarRondas(String nvo)
	#{
	#	self.rondas = nvo;
	#}

    #def __str__(self):
    #
    #

    #def __eq__(self, otro):
    #
    #

    #def __ne__(self, otro):
    #
    #
